# %% [markdown]
# Завдання 1. Ми обговорили з Вами на лекції, що велика літера Сігма грецького алфавіту позначає в математиці суму. Знайдіть з використанням Python  Σ𝑥 ,  Σ𝑥2 , та  Σ(𝑥−1)2  для наступного набору даних: 1 3 4 Виведіть результат кожного обчислення на екран.

# %%
x = [1, 3, 4]
sum_x = sum(x)
print(sum_x)
# Out:
# 8

# %%
sum_x2 = sum(i ** 2 for i in x)
print(sum_x2)
# Out:
# 26

# %%
sum_x_minus = sum((i - 1) ** 2 for i in x)
print(sum_x_minus)
# Out:
# 13

# %% [markdown]
# Завдання 2. Ми зібрали дані про суму покупок в гривнях 20ма випадково обраними клієнтами в нашому магазині (всього клієнтів у нас більше) за минулий місяць. Вони представлені в змінній sum_purchases. Знайдіть вибіркове середнє для цих даних кожним з зазначених методів:
#
# 2.1. без використання жодних бібліотек, користуючись тільки Python.
# 2.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат обчислень в кожному з випадків на екран та порівняйте результати. Вони співпадають?

# %%
# python
sum_purchases = [ 316,  493,  367,  153,  224,  121,  322,  450,  196,  397,  281,
  239,  484,  124,  223,  448,  432,  255, 4310, 3524]
mean_sum_purchases = sum(sum_purchases) / len(sum_purchases)
print(f'Вибіркове середнє:  ', mean_sum_purchases)
# Out:
# Вибіркове середнє:   667.95

# %%
# numpy
import numpy as np
sum_purchases = [ 316,  493,  367,  153,  224,  121,  322,  450,  196,  397,  281,
  239,  484,  124,  223,  448,  432,  255, 4310, 3524]
mean_numpy = np.mean(sum_purchases)
print(f'Вибіркове середнє: ', mean_numpy)
print("Результати у Python і Numpy співпадають.")
# Out:
# Вибіркове середнє:  667.95
# Результати у Python і Numpy співпадають.

# %% [markdown]
# Завдання 3. Для того ж набору даних в змінній sum_purchases обчисліть медіану кожним з зазначених методів:
#
# 3.1. без використання жодних бібліотек, користуючись тільки Python.
# 3.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат обчислень в кожному з випадків на екран. Порівняйте результати зі значенням вибіркового середнього. Напишіть коментар, для яких задач ви б використовували вибіркове середнє, а для яких - медіану?

# %%
# python median
sum_purchases = [ 316,  493,  367,  153,  224,  121,  322,  450,  196,  397,  281,
  239,  484,  124,  223,  448,  432,  255, 4310, 3524]
sorted_sum_purchases = sorted(sum_purchases)
print(f'Відсортований список: ', sorted_sum_purchases)
length_list = len(sorted_sum_purchases)
print(f'Довжина парна: ', length_list) # парна кіль-ть елементів - 20 ---> медіана - середнє двох серединних елементів
python_median = (sorted_sum_purchases[length_list // 2 - 1] + sorted_sum_purchases[length_list // 2])/2
print(f'Медіана: ',  python_median)
# Out:
# Відсортований список:  [121, 124, 153, 196, 223, 224, 239, 255, 281, 316, 322, 367, 397, 432, 448, 450, 484, 493, 3524, 4310]
# Довжина парна:  20
# Медіана:  319.0

# %%
# numpy median
numpy_median = np.median(sum_purchases)
print(f'Медіана: ', numpy_median)
# Out:
# Медіана:  319.0

# %% [markdown]
# 1. Через те, що у списку є дві суми покупок, що суттєво більші за решту значень, вибіркове середнє більше, ніж медіана.
# 2. Коли нам треба врахувати всі дані, наприклад, для підсумку середньої суми покупок за місяць, то рахуємо вибіркове середнє. Але, якщо цікавить тенденція, при асиметричних даних, то рахуємо медіану.

# %% [markdown]
# Завдання 4. Обчислість стандартне відхилення наведеної вибірки в змінній sum_purchases кожним з зазначених методів:
#
# 4.1. без використання жодних бібліотек, користуючись тільки Python.
# 4.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат обчислень в кожному з випадків на екран.

# %%
# std python
sum_purchases = [ 316,  493,  367,  153,  224,  121,  322,  450,  196,  397,  281,
  239,  484,  124,  223,  448,  432,  255, 4310, 3524]
n = len(sum_purchases)
mean_sum_purchases = sum(sum_purchases) /n
sum_squared_diff = 0
for el in sum_purchases:
    sum_squared_diff += (el - mean_sum_purchases) ** 2
std_python = (sum_squared_diff/(n - 1)) ** 0.5
print(f'Стандартне відхилення через Python:', round(std_python, 2))
# Out:
# Стандартне відхилення через Python: 1124.54

# %%
# std numpy
std_numpy = np.std(sum_purchases, ddof = 1)
print(f'Стандартне відхилення через Numpy:', round(std_numpy, 2))
# Out:
# Стандартне відхилення через Numpy: 1124.54

# %% [markdown]
# Завдання 5. Ми провели дослідження віку студентів-першокурсників. Виявилось, що
#
# 10 студентів мають вік 16 років
# 25 студентів - 17 років
# 20 студентів - 18 років
# 2 студенти - 20 років
# Обчислість середнє значення для цієї вибірки будь-яким способом - на чистому Python або з numpy - та виведіть результат на екран.

# %%
# python
age = [16, 17, 18, 20]
amount = [10, 25, 20, 2]
students_amount = sum(amount)
mean_age = sum(age * amount for age, amount in zip(age, amount))/students_amount
print(f'Середній вік студентів: ', round(mean_age))
# Out:
# Середній вік студентів:  17

# %%
# numpy
age = np.array([16, 17, 18, 20])
amount = np.array([10, 25, 20, 2])
mean_age = np.average(age, weights = amount)
print(f'Середній вік студентів: ', round(mean_age))
# Out:
# Середній вік студентів:  17

# %% [markdown]
# Завдання 6. Крім даних про суму покупок, ми зібрали ще дані про кількість відвідувань кожного з кожного покупця, які знаходяться в змінній visits. Обчисліть коефіцієнт кореляції Пірсона для суми покупок і кількості відвідувань кожним з зазначених методів:
#
# 6.1. без використання жодних бібліотек, користуючись тільки Python.
# 6.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат на екран. Проаналізуйте результат.
#
# Виведіть додатково графік розсіювання викликавши код нижче і зробіть заключення, чи варто щось змінити при підрахунку кореляції, аби коефіцієнт Пірсона показував коректну оцінку лінійної залежності?

# %%
# python
sum_purchases = [ 316,  493,  367,  153,  224,  121,  322,  450,  196,  397,  281,
  239,  484,  124,  223,  448,  432,  255, 4310, 3524]
visits = [ 6,  2, 10,  3,  9,  9,  2,  3,  6,  6, 10,  2,  5, 10,  3,  5,  4,
        7,  4,  2]
# equal amount or not
len(sum_purchases)
len(visits)
# mean
mean_x = sum(sum_purchases) / len(sum_purchases)
mean_y = sum(visits) / len(visits)

# sum of products of deviations from the means
numerator = sum((x - mean_x) * (y - mean_y) for x, y in zip(sum_purchases, visits))

# sum of squared deviations
sum_sq_x = sum((x - mean_x)**2 for x in sum_purchases)
sum_sq_y = sum((y - mean_y)**2 for y in visits)

# Pearson correlation
r_python = numerator / (sum_sq_x**0.5 * sum_sq_y**0.5)

print("Коефіцієнт кореляції Пірсона через Python:", round(r_python, 1))
# Out:
# Коефіцієнт кореляції Пірсона через Python: -0.3

# %%
# numpy Pearson correlation
r_numpy = np.corrcoef(sum_purchases, visits)[0, 1]
print("Коефіцієнт кореляції Пірсона через NumPy:", round(r_numpy, 1))
# Out:
# Коефіцієнт кореляції Пірсона через NumPy: -0.3

# %% [markdown]
# Коефіцієнт кореляції Пірсона = -0.3, що говорить про негативну кореляцію (коли один показник росте, інший -- має тенденцію спаду). Сума покупок слабо пов'язане з кількістю відвідувань.

# %%
import matplotlib.pyplot as plt

plt.scatter(sum_purchases, visits)
plt.title('Scatter Plot of Purchases vs. Visits')
plt.xlabel('Sum of Purchases')
plt.ylabel('Number of Visits');

# %% [markdown]
# Дві великі суми покупок у даних (точки внизу праворуч) зумовлюють негативну кореляцію Пірсона, вони є викидами. Краще їх не брати до розрахунку.

# %% [markdown]
# Завдання 7. В попередньому завданні ми помітили, що викиди нам заважають отримати "правдиве" значення кореляції. Давайте вилучимо записи, які відповідають значенням з викидами в сумі покупок і обчисліть коеф. кореляції. Для цього поставте threshold, який дорінює середньому значенню + 2 стандартних вдіхилля суми покупок і всі значення, які більше за нього, будемо вважати викидами (є і інші правила для визначення викидів - з ним и познайомимось пізніше).
#
# Вилучіть значення з обох масивів і обчисліть коеф. кореляції Пірсона з допомогою numpy для кількості візитів і суми покупок без записів-викидів. Виведіть результат на екран, побудуйте діаграму розсіювання і проаналізуйте результат: що можемо сказати про залежність в даних?

# %%
# add treshold
mean_purchases = np.mean(sum_purchases)
std_purchases = np.std(sum_purchases, ddof=1)
threshold = mean_purchases + 2 * std_purchases
print("Threshold:", threshold)
# Out:
# Threshold: 2917.0366894902263

# %%
# remove values
filtered_purchases =[]
filtered_visits =[]
for purchase, visit in zip(sum_purchases, visits):
    if purchase <= threshold:
        filtered_purchases.append(purchase)
        filtered_visits.append(visit)
print(len(filtered_purchases))
# Out:
# 18

# %%
# Pearson correlation
corr_filtered = np.corrcoef(filtered_purchases, filtered_visits)[0, 1]
print(round(corr_filtered))
# Out:
# 0

# %%
# scatter plot
plt.scatter(filtered_purchases, filtered_visits)
plt.title('Scatter Plot of Purchases vs. Visits')
plt.show()

# %% [markdown]
# Після видалення викидів, кореляції все одно немає -- напрямок відсутній, результат 0 після округлення. Так само -- кількість відвідувань не пов'язане з сумою покупок. Значить, питання в даних.
