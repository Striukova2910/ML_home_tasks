# %% [markdown]
# 1. Цикл for - базовий
#
# Використовуючи цикл for, виведіть числа від 1 до 7 включно використовуючи функцію range.

# %%
for i in range(1,8):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# 2. Цикл for по списку
# Дано список:
# names = ["Олег", "Анна", "Іван", "Марія"]
# Використовуючи цикл, виведіть кожне ім'я з привітанням: "Привіт, [ім'я]!"

# %%
names = ["Oleh", "Anna", "Ivan", "Maria"]
for i in names:
    print(f"Hello {i}!")
# Out:
# Hello Oleh!
# Hello Anna!
# Hello Ivan!
# Hello Maria!

# %% [markdown]
# 3. Цикл з enumerate
# Дано список оцінок:
# grades = [85, 92, 78, 95, 88]
# Використовуючи enumerate, виведіть кожну оцінку з номером: "Студент 1: 85 балів"

# %%
grades = [85, 92, 78, 95, 88]
for i, grade in enumerate(grades):
    print(f"Student {i+1}: {grade} grades")
# Out:
# Student 1: 85 grades
# Student 2: 92 grades
# Student 3: 78 grades
# Student 4: 95 grades
# Student 5: 88 grades

# %% [markdown]
# 4. Сума парних чисел
# Напишіть програму, яка обчислює суму всіх парних чисел від 1 до 20.

# %%
sum_even = 0
for i in range(1,21):
    if i % 2 == 0:
        sum_even += i
print(f"Sum of even numbers equals: ", sum_even)
# Out:
# Sum of even numbers equals:  110
